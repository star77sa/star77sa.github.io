# %% [raw]
# ---
# title: "[Random Process] Probability, Random Variable"
# author: "고경수"
# date: "06/14/2024"
# reference-location: margin
# citation-location: margin
# cap-location: margin
# ---

# %% [markdown]
# ![](attachment:image.png)
